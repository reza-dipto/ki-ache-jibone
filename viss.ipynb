# %%
# !pip install d3blocks
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.4/1.4 MB 17.8 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 124.6/124.6 kB 15.6 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 82.8/82.8 kB 10.7 MB/s eta 0:00:00
# ...
#   Attempting uninstall: markupsafe
#     Found existing installation: MarkupSafe 2.1.3
#     Uninstalling MarkupSafe-2.1.3:
#       Successfully uninstalled MarkupSafe-2.1.3
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# lida 0.0.10 requires fastapi, which is not installed.
# lida 0.0.10 requires kaleido, which is not installed.
# lida 0.0.10 requires python-multipart, which is not installed.
# lida 0.0.10 requires uvicorn, which is not installed.
# werkzeug 3.0.0 requires MarkupSafe>=2.1.1, but you have markupsafe 2.0.1 which is incompatible.
# ...

# %%
from google.colab import files
uploaded = files.upload()
# Out:
#      <input type="file" id="files-ff8a7506-027d-4ec1-a703-aef25f77af64" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-ff8a7506-027d-4ec1-a703-aef25f77af64">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
import pandas as pd

# %%
df = pd.read_excel("mydataln.xlsx")

# %%
df.head()
# Out:
#     datetime  sample_id     state
# 0 2000-01-01          1  Sleeping
# 1 2000-01-01          2  Sleeping
# 2 2000-01-01          3  Sleeping
# 3 2000-01-01          4  Sleeping
# 4 2000-01-01          5  Sleeping

# %%
from d3blocks import D3Blocks
d3 = D3Blocks()
# Out:
# [d3blocks] >INFO> Cleaning edge_properties and config parameters..

# %%
d3.movingbubbles(
    df,
    speed={"fast": 40,
           "medium":100,
           "slow":500},
    filepath='movingbubbles_Final_1.html',
    figsize = [780,800],
    center='Travel to work'


    )
# Out:
# [d3blocks] >INFO> Cleaning edge_properties and config parameters..
# [d3blocks] >INFO> Initializing [Movingbubbles]
# [d3blocks] >INFO> filepath is set to [/tmp/d3blocks/movingbubbles_Final_1.html]
# [d3blocks] >INFO> Set the center state at: [Travel to work]
# [d3blocks] >INFO> Convert to DataFrame.
# [d3blocks] >INFO> Node properties are set.
# [d3blocks] >INFO> Standardizing input dataframe using method: [samplewise].
# [d3blocks] >INFO> Standardize method: [samplewise]
# 100%|██████████| 800/800 [00:06<00:00, 129.26it/s]
# [d3blocks] >INFO> Set all nodes to size: 5
# [d3blocks] >WARNING> Colormap [Set1] can not create [800] unique colors! Available unique colors: [9].
# [d3blocks] >INFO> Edge properties are set.
# [d3blocks] >INFO> Open browser: /tmp/d3blocks/movingbubbles_Final_1.html
